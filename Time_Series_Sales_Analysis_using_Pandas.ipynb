# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "date" : pd.date_range(start="2023-01-01",periods=180,freq="D"),
    "sales" : [200 + i*2 for i in range(180)]
}
df = pd.DataFrame(data)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.set_index("date",inplace=True)

# %%
df.head()
# Out:
#             sales
# date
# 2023-01-01    200
# 2023-01-02    202
# 2023-01-03    204
# 2023-01-04    206
# 2023-01-05    208

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["sales"])
plt.title("Daily Sales Trend")
plt.xlabel("date")
plt.ylabel("sales")
plt.show()

# %%
df["rolling_7"] = df["sales"].rolling(window=7).mean()
plt.figure(figsize=(10,5))
plt.plot(df.index,df["sales"],label="Daily Sales Trends")
plt.plot(df.index,df["rolling_7"],label="7-Day Average")
plt.legend()
plt.show()

# %%
monthly_sales = df.resample("ME")["sales"].sum()
monthly_sales.plot(kind='bar',figsize=(8,4))
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Total sales")
plt.show()

# %%
monthly_sales = df["sales"].resample("ME").sum()
monthly_sales.head()
# Out:
# date
# 2023-01-31     7130
# 2023-02-28     8092
# 2023-03-31    10788
# 2023-04-30    12270
# 2023-05-31    14570
# Freq: ME, Name: sales, dtype: int64
